# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/dahenderson98/MachineTranslation/blob/main/translation.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# #The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances. Think about what each dimension means to find out which dimensions you'll want to perform each operation on.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clones()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
# !pip install torch==1.9.0

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext==0.10.0
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ## Implement Attention
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
class Attention(nn.Module):
  def __init__(self, h, d_model, dropout=0.1):
    super(Attention, self).__init__()
    self.h = h
    self.d_model = d_model
    self.dropout = dropout

    self.to_keys    = nn.Linear(d_model, d_model, bias=False)
    self.to_queries = nn.Linear(d_model, d_model, bias=False)
    self.to_values  = nn.Linear(d_model, d_model, bias=False)

  def forward(self, query, key, value, mask):
    # Transform query, key and value
    K = self.to_keys(key)
    Q = self.to_queries(query)
    V = self.to_values(value)

    scores = torch.bmm(Q, K.transpose(-2,-1)) / self.d_model**(1/2)
    
    # Apply mask
    if mask is not None:
      scores = scores.masked_fill(mask == 0, -1e9)

    output = torch.bmm( F.softmax(scores, dim=2), V )

    return output

# %%
def attention(query, key, value, mask):
  
  # Compute 'Scaled Dot Product Attention'
  # scores = Q*K^T/scale
  scores = torch.bmm(query, key.transpose(1, 2)) / key.size(2)**(1/4)
  
  # Apply the mask
  if mask is not None:
    scores = scores.masked_fill(mask == 0, -1e9)
      
  output = torch.bmm(F.softmax(scores, dim=2), value)
  
  return output

# %%
class MultiHeadedAttention(nn.Module):
  def __init__(self, h, d_model, dropout=0.1):
    super(MultiHeadedAttention, self).__init__()
    
    # etc.
    # These compute the queries, keys and values for all
    # heads (as a single concatenated vector)
    self.h = h
    self.d_model = d_model

    self.attention = Attention(h, d_model, dropout=0.1)
    self.heads = clones(self.attention, h)

    self.shrinker = nn.Linear(h * d_model, d_model, bias=False)

    # This unifies the outputs of the different heads into
    # a single k-vector
    #self.unify_heads = nn.Linear(h * d_model, d_model)

  def forward(self, query, key, value, mask):
    # For each attention head
        # Pass the query, key, value through their respective layers
        # Compute scaled dot-product attention on the output
    # etc.
    outputs = []
    for i, mod in enumerate(self.heads):
      outputs.append(mod(query, key, value, mask))
    
    # concat all outputs, linear transform back to correct size
    cat = torch.cat(tuple(outputs),-1)
    #print("Cat_d: ",cat.size())

    # return final output
    shrunk = self.shrinker(cat)
    
    return shrunk

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es_core_news_sm')
spacy_en = spacy.load('en_core_web_sm')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
with open('./spanish', 'r', encoding='utf-8') as spanish_text:
  spanish_lines = list(spanish_text)
with open('./english', 'r', encoding='utf-8') as english_text:
  english_lines = list(english_text)

fields = (["src", SRC], ["trg", TGT])
examples = [data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ## Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 10
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        run_epoch((rebatch(pad_idx, b) for b in train_iter), 
                  model, 
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# Epoch Step: 1 Loss: 8.675403 Tokens per Sec: 3666.538574
# Epoch Step: 51 Loss: 5.733795 Tokens per Sec: 10418.821289
# Epoch Step: 101 Loss: 5.536590 Tokens per Sec: 10237.689453
# Epoch Step: 151 Loss: 5.657354 Tokens per Sec: 10656.847656
# Epoch Step: 201 Loss: 5.321265 Tokens per Sec: 9833.266602
# Epoch Step: 251 Loss: 4.801089 Tokens per Sec: 10323.557617
# Epoch Step: 301 Loss: 4.993378 Tokens per Sec: 10868.885742
# Epoch Step: 351 Loss: 5.147435 Tokens per Sec: 10390.646484
# Epoch Step: 401 Loss: 5.387830 Tokens per Sec: 9921.007812
# Epoch Step: 451 Loss: 4.560198 Tokens per Sec: 11001.864258
# Epoch Step: 501 Loss: 4.971787 Tokens per Sec: 10877.982422
# Epoch Step: 901 Loss: 1.871672 Tokens per Sec: 11072.556641
# Epoch Step: 951 Loss: 1.546327 Tokens per Sec: 9733.618164
# Epoch Step: 1001 Loss: 1.354117 Tokens per Sec: 11295.393555
# Epoch Step: 1051 Loss: 1.404796 Tokens per Sec: 11099.068359
# Epoch Step: 1101 Loss: 1.576457 Tokens per Sec: 10024.562500
# Epoch Step: 1151 Loss: 1.594339 Tokens per Sec: 11060.348633
# Epoch Step: 1201 Loss: 1.401399 Tokens per Sec: 11098.698242
# Epoch Step: 1251 Loss: 1.537463 Tokens per Sec: 8952.887695
# Epoch Step: 1301 Loss: 1.463696 Tokens per Sec: 10277.297852

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	A-G-U-A .
# Translation:	A crushing flower is .
# Target:		W - A - T - E - R .
#
# Spanish:	Octubre de 2016
# Translation:	October 2016
# Target:		October 2016
#
# Spanish:	Él explicó :
# Translation:	He explained :
# Target:		He explained :
#
# Spanish:	<unk> de la tormenta
# Translation:	Minor defects
# Target:		Storm <unk>
#
# Spanish:	Véase Isaías 1:18 .
# Translation:	See Isaiah 1:18 .
# Target:		See Isaiah 1:18 .
#
# Spanish:	Enseñanzas para nuestra época
# Translation:	Teachings for Our Time
# Target:		Teachings for Our Time
#
# Spanish:	Véase Hechos 26:24 .
# Translation:	See Acts 82:6 .
# Target:		See Acts 26:24 .
#
# Spanish:	Apenarte ya no deseo
# Translation:	I Wish Not Do Not
# Target:		I no longer wish to grieve Thee
#
# Spanish:	2 de octubre de 2016
# Translation:	October 02 , 2016
# Target:		October 02 , 2016
#
# Spanish:	¿ No es emocionante ?
# Translation:	Is n’t it Hard ?
# Target:		Is n’t that exciting ?
#
# Spanish:	Jesús es el Cristo .
# Translation:	Jesus is the Christ .
# Target:		Jesus is the Christ .
#
# Spanish:	Doctrina y Convenios 6:36 .
# Translation:	Doctrine and Covenants 6:36 .
# Target:		Doctrine and Covenants 6:36 .
#
# Spanish:	Siempre ha sido así .
# Translation:	It has always been so .
# Target:		It has always been this way .
#
# Spanish:	La recibiremos al ganar .
# Translation:	We will receive it .
# Target:		We shall win and wear it by and by .
#
# Spanish:	En la revelación se registra :
# Translation:	In revelation , the revelation records :
# Target:		The revelation records :
#
# Spanish:	Por el élder Gary E. Stevenson
# Translation:	By Elder Gary E. Stevenson
# Target:		By Elder Gary E. Stevenson
#
# Spanish:	Última oración : <unk> <unk> .
# Translation:	Benediction : Reyna I. Aburto .
# Target:		Benediction : <unk> <unk> .
#
# Spanish:	El sacerdocio : Un don sagrado
# Translation:	The priesthood :
# Target:		The Priesthood — a Sacred Gift
#
# Spanish:	Ya conocen los principios fundamentales .
# Translation:	You know the foundational principles .
# Target:		You already know the fundamentals .
#
# Spanish:	Jesucristo ha vencido al mundo ;
# Translation:	Jesus Christ has overcome the world .
# Target:		Jesus Christ has overcome the world .
#
# Spanish:	la senda Él nos indicó :
# Translation:	He gave us the way :
# Target:		And glory great and bliss are ours ,
#
# Spanish:	<unk> llegar al valle ’ .
# Translation:	Minor defects , ’ valley .
# Target:		We ’re going to make it to the valley . ’
#
# Spanish:	¿ Por qué tan terrible tribulación ?
# Translation:	Why did this terrible tribulation ?
# Target:		Why such terrible tribulation ?
#
# Spanish:	Los dos tienen una necesidad específica .
# Translation:	The two need a need for two .
# Target:		Each has a specific need .
#
# Spanish:	Dirige : Presidente Dieter F. Uchtdorf .
# Translation:	Conducting : President Dieter F. Uchtdorf .
# Target:		Conducting : President Dieter F. Uchtdorf .
#
# Spanish:	El Señor Jesucristo nos enseña a orar
# Translation:	The Lord Jesus Christ Teaches Us to Pray
# Target:		The Lord Jesus Christ Teaches Us to Pray
#
# Spanish:	cosas de Cristo , quisiera escuchar .
# Translation:	Let ’s things , that I would hear .
# Target:		Stories of Jesus , tell them to me .
#
# Spanish:	Podemos <unk> al hacernos unas preguntas .
# Translation:	We can be resolved to each other .
# Target:		We might test ourselves by asking a few questions .
#
# Spanish:	Ella levantó la vista y nos sonrió .
# Translation:	She took her eyes and tried .
# Target:		She looked up and smiled .
#
# Spanish:	Última oración : Élder Shayne M. Bowen .
# Translation:	Benediction : Elder Choi .
# Target:		Benediction : Elder Shayne M. Bowen .
#
# Spanish:	Véase 1 Pedro 1:6–8 ; Abraham 3:25 .
# Translation:	See 1 Peter 3:15 ; Abraham 3:22 .
# Target:		See 1 Peter 1:6–8 ; Abraham 3:25 .
#
# Spanish:	Jesucristo es también la fuente de paz .
# Translation:	Jesus Christ is also the source of peace .
# Target:		Jesus Christ is also the source of peace .
#
# Spanish:	Recuerdo Su ejemplo durante los días anteriores .
# Translation:	I remember His example during the past few days .
# Target:		I remember His example in the days before .
#
# Spanish:	Es hermosamente sencillo y funciona de maravilla .
# Translation:	It is beautifully simple and it .
# Target:		It is beautifully simple , and it works beautifully .
#
# Spanish:	cosas que yo de sus labios quisiera oír
# Translation:	I that I would like to hear his words , I would hear you hear from his mouth I could hear his words from his mouth I could hear that I would have my lips .
# Target:		Things I would ask him to tell me if he were here .
#
# Spanish:	Debido a mi profesión , yo viajaba mucho .
# Translation:	Because of my career , I was a lot .
# Target:		I traveled extensively in my profession .
#
# Spanish:	<unk> es una madre joven con dos niñas .
# Translation:	She is a mother with two young woman .
# Target:		<unk> is a young mother of two .
#
# Spanish:	Esta mañana celebramos Su victoria sobre la muerte .
# Translation:	This morning His victory over death .
# Target:		We celebrate this morning His victory over death .
#
# Spanish:	Mateo <unk> ; véase también 3 Nefi <unk> .
# Translation:	Matthew 25:35–36 , see also 3 Nephi 13:10 .
# Target:		Matthew <unk> ; see also 3 Nephi <unk> .
#
# Spanish:	El recorrido del discipulado no es uno fácil .
# Translation:	The journey of discipleship is not easy .
# Target:		The journey of discipleship is not an easy one .
#
# Spanish:	Coro ( sin <unk> nuevo mandamiento os doy "
# Translation:	Choir ( without announcement ): " I Have Chosen "
# Target:		Choir ( without <unk> New Commandment I Give unto You "
#
# Spanish:	Hemos sentido el Espíritu del Señor en abundancia .
# Translation:	We have felt the Spirit of the Lord .
# Target:		We have felt the Spirit of the Lord in rich abundance .
#
# Spanish:	Informe del Departamento de Auditorías de la Iglesia , 2016
# Translation:	Church Auditing Department Report , 2016
# Target:		Church Auditing Department Report , 2016
#
# Spanish:	El hermano Wacker se <unk> la vida como <unk> .
# Translation:	Brother Renlund is maintained by the life of scorn at the ingenuity .
# Target:		Brother Wacker earned his living as a <unk> .
#
# Spanish:	Las asociaciones con los líderes son importantes y significativas .
# Translation:	The leaders are important and important leaders .
# Target:		Relationships with leaders are so important and significant .
#
# Spanish:	Véase Helamán <unk> ; Éter 12:27 ; Moroni 10:32–33 .
# Translation:	See Helaman 7:9 ; Ether 12:27 ; Moroni 10:32–33 .
# Target:		See Helaman <unk> ; Ether 12:27 ; Moroni 10:32–33 .
#
# Spanish:	El equipo de fútbol americano ganó el campeonato estatal .
# Translation:	The football team won the football team .
# Target:		The football team went on to win the state title .
#
# Spanish:	Sí , siempre hay algo imperfecto en cualquier situación .
# Translation:	Yes , there is always something wrong in any circumstance .
# Target:		Yes , there is always something imperfect in any situation .
#
# Spanish:	Debemos venir a Él y permitirle efectuar Sus milagros .
# Translation:	We must come to Him and give miracles .
# Target:		We must come unto Him and allow Him to work His miracles .
#
# Spanish:	Notas de dirección de la sesión del sábado por la mañana
# Translation:	Sun AM Conducting Notes
# Target:		<unk> AM Conducting Notes
#
# Spanish:	¿ Qué es lo que el Señor desea que hagan ?
# Translation:	What is what does the Lord wants you ?
# Target:		What does the Lord want you to do ?
#
# Spanish:	Discursos publicados en la revista Liahona * de noviembre de 2011
# Translation:	Talks published in the Liahona and Ensign *
# Target:		Talks published in the November 2011 Liahona and Ensign *
#
# Spanish:	Cansada de lo vano , lo vulgar y lo vil ,
# Translation:	Tired from the fall , and evil , and iniquity , and the be of .
# Target:		Tired of the hollow , the base , the untrue ,
#
# Spanish:	“ La Familia : Una Proclamación para el Mundo ” .
# Translation:	“ The Family : A Proclamation to the World . ”
# Target:		“ The Family : A Proclamation to the World . ”
#
# Spanish:	A fin de entender , tenemos que <unk> al comienzo .
# Translation:	To understand , we have the following as we move forward .
# Target:		To understand , we have to go back to the beginning .
#
# Spanish:	Naturalmente , Jesucristo es la perfecta personificación de la caridad .
# Translation:	Of course , Jesus Christ is perfect .
# Target:		Of course , Jesus Christ is the perfect embodiment of charity .
#
# Spanish:	El lugar perfecto para empezar es exactamente donde están ahora .
# Translation:	The perfect place for it is exactly where we now are .
# Target:		The perfect place to begin is exactly where you are right now .
#
# Spanish:	Ellos los conocen , velan por ustedes y los aman .
# Translation:	They know them , they watch over you and love them .
# Target:		They know you , They watch over you , and They love you .
#
# Spanish:	Bruce R. McConkie , 1978 , tomo I , pág. 27 .
# Translation:	Bruce R. McConkie , in July 26 , 27 , 27 .
# Target:		Bruce R. McConkie ( 1955 ) , 1:27 .
#
# Spanish:	Cuarto , debemos actuar y obedecer al sentir el primer susurro .
# Translation:	Fourth , we must act and act on the first prompting .
# Target:		Fourth , we must act on the first prompting .
#
# Spanish:	Hace muchos años , una de nuestras hijas estaba notablemente angustiada .
# Translation:	Many years ago , a daughter of our daughters was born .
# Target:		Many years ago one of our children was <unk> distressed .
#
# Spanish:	Entonces , me preguntó : “ ¿ Tiene tiempo ? ” .
# Translation:	Then he asked , “ Does it have time ? ”
# Target:		He then asked me , “ Do you have time ? ”
#
# Spanish:	Estos discursos están disponibles ( en muchos idiomas ) en conference.lds.org .
# Translation:	These talks are available ( in many languages ) in conference.lds.org .
# Target:		These talks are available ( in many languages ) at conference.lds.org .
#
# Spanish:	En aquella época , teníamos barrios y ramas en 59 países .
# Translation:	In that time we were , and we were born in countries , countries , countries , countries , countries , countries , and we had lived in that time , we had lived .
# Target:		At that time , our wards and branches were in 59 countries .
#
# Spanish:	Ustedes son el milagro de esta Iglesia , y los amamos .
# Translation:	You are the miracle of this Church , and we love the Church .
# Target:		You are the miracle of this Church . And we love you .
#
# Spanish:	No implica que estaremos libres del dolor o de la angustia ;
# Translation:	It does not mean that we will be free from grief or sorrow .
# Target:		It does not imply that we will be free from pain or heartache .
#
# Spanish:	Quería poner mi entusiasmo y mi fe en Jesucristo en acción .
# Translation:	I wanted to have my faith and was in Jesus Christ .
# Target:		I wanted to put my excitement and my faith in Jesus Christ into action .
#
# Spanish:	haciendo caso omiso de mis súplicas de que no fueran tan rápido .
# Translation:	They ignored my petitions to slow down to my petitions to so quickly .
# Target:		They ignored my petitions to slow down .
#
# Spanish:	Nos regocijamos por todo lo que el Salvador ha hecho por nosotros .
# Translation:	We rejoice in all that the Savior has done for us .
# Target:		We rejoice in all the Savior has done for us .
#
# Spanish:	<unk> todo lo que pude para saber más acerca de la universidad .
# Translation:	She joins everything I could know about what I could .
# Target:		I dug into everything I could learn about the university .
#
# Spanish:	En lugar de ello , adoptamos los atributos cristianos que Jesús enseñó :
# Translation:	In this regard , the attributes of Jesus taught that Christians :
# Target:		Rather , we take on the Christlike qualities that Jesus taught :
#
# Spanish:	Un espíritu contrito se manifiesta por nuestro deseo y determinación de actuar .
# Translation:	A spirit is saved by our desire to act and act .
# Target:		A contrite spirit is manifest by our willingness and determination to act .
#
# Spanish:	Recordar — y olvidar — también son parte de nuestra jornada eterna .
# Translation:	To remember , and let ’s also forget our eternal journey .
# Target:		Remembering — and forgetting — are also part of our eternal journey .
#
# Spanish:	El mundo alrededor de la pareja desaparece y se sienten sumamente felices .
# Translation:	The world around the couple has been and felt helpless .
# Target:		The world disappears around the couple , and they experience feelings of joy .
#
# Spanish:	Permítanme dar una sola referencia que tiene aplicación inmediata en nuestra vida .
# Translation:	Let me tell me one of a very early life in our lives .
# Target:		Let me provide but one reference which has immediate application to our lives .
#
# Spanish:	El Señor no lo hizo fácil , pero sí lo hizo posible .
# Translation:	The Lord did not mean it , but he did it .
# Target:		The Lord did not make it easy , but He did make it possible .
#
# Spanish:	Habrá momentos en su vida en los que serán llamados a liderar .
# Translation:	There will be times in your life as you are called to lead .
# Target:		There will be times in your life when you are called upon to lead .
#
# Spanish:	James E. Talmage , Jesús el Cristo , 1982 , pág. <unk> .
# Translation:	James E. Talmage , Jesus the Christ , 3rd ed . ( 1916 ) , 139 .
# Target:		James E. Talmage , Jesus the Christ , 3rd ed . ( 1916 ) , <unk> .
#
# Spanish:	Todos podemos recordar nuestros sentimientos cuando un niño nos ha pedido ayuda .
# Translation:	We all can remember our feelings when we have a help .
# Target:		We can all remember our feelings when a little child cried out and reached up to us for help .
#
# Spanish:	Hice eso hace poco , y anoté a cada miembro de mi familia .
# Translation:	I made this little bit , and I made a family unit .
# Target:		I did this recently , listing each family member .
#
# Spanish:	“ El aprender a confiar en Él ha marcado toda la diferencia ” .
# Translation:	“ You learn to trust Him has every one of the difference . ”
# Target:		“ Learning to trust Him has made all the difference . ”
#
# Spanish:	“ ¡ Mire hacia allá ! ” , uno de ellos dijo enojado .
# Translation:	“ Look there to them , ” he said , “ Grandpa , Grandpa .
# Target:		“ Look out there , ” one of them angrily told me .
#
# Spanish:	A causa de nuestra creencia , nunca tendremos hambre , nunca tendremos sed .
# Translation:	Because of our belief , we will never have a stranger .
# Target:		Because of our belief , we will never hunger , never thirst .
#
# Spanish:	La última oración la ofrecerá el élder Hugo Montoya , de los Setenta .
# Translation:	The benediction will then be offered by Elder Hugo Montoya of the Seventy .
# Target:		The benediction will then be offered by Elder Hugo Montoya of the Seventy .
#
# Spanish:	Eso es parte del gran plan de felicidad que el Padre nos dio .
# Translation:	That is part of the great plan of happiness that gave us .
# Target:		That is part of the great plan of happiness the Father gave us .
#
# Spanish:	Hace poco anunciamos un nuevo templo que se edificará en Payson , Utah .
# Translation:	We announced a new temple new temple who is formed , Utah .
# Target:		Recently we announced a new temple which will be built in Payson , Utah .
#
# Spanish:	¡ Qué gran bendición es cuando el Espíritu del Señor amplía nuestra visión !
# Translation:	What a great blessing is the Spirit of the Lord !
# Target:		What a blessing it is when the Spirit of the Lord <unk> our view .
#
# Spanish:	Una de las grandes bendiciones del plan es que estamos organizados en familias .
# Translation:	One of the great blessings of the plan of salvation is organized .
# Target:		One of the great blessings of the plan is that we are organized into families .
#
# Spanish:	Pero aunque hablaba esas palabras en su corazón , no oía ninguna contestación .
# Translation:	But while speaking of those words , I heard no answer .
# Target:		But although she spoke these words in her heart , she could hear nothing in reply .
#
# Spanish:	“ A donde me mandes iré ” , Himnos , nro . 175 .
# Translation:	“ You ’ll go where I ’ll Go , ” Hymns , no . 270 .
# Target:		“ I ’ll Go Where You Want Me to Go , ” Hymns , no . 270 .
#
# Spanish:	Dicho gozo llega como una paz en medio de la adversidad o del pesar .
# Translation:	That joy comes as a peace in adversity or adversity .
# Target:		That joy comes as peace amidst hardship or heartache .
#
# Spanish:	Este diseño también permitiría llevar a cabo el proyecto de jardines sobre el tejado .
# Translation:	This also provides to carry out the facilities of the project on the project .
# Target:		This design also would accommodate the <unk> plans for the roof .
#
# Spanish:	El Señor lo fortaleció y él venció las pruebas a las que hizo frente .
# Translation:	The Lord will strengthen him and have trials to come to the trials that did it .
# Target:		The Lord strengthened him , and he overcame the trials he faced .
#
# Spanish:	Para describir su experiencia en el templo , ellos emplearon frases como las siguientes :
# Translation:	To describe his experience in the temple , I have been like the following as the following :
# Target:		They used phrases like the following to describe their experience in the temple :
#
# Spanish:	Décadas de inestabilidad política y guerras civiles han empeorado los efectos de la pobreza .
# Translation:	Decades of political instability and civil wars have worsened the plague of poverty .
# Target:		Decades of political instability and civil wars have worsened the plague of poverty .
#
# Spanish:	La última oración la ofrecerá el élder Massimo De Feo , de los Setenta .
# Translation:	The benediction will then be offered by Elder De Feo , the Seventy .
# Target:		The benediction will then be offered by Elder Massimo De Feo of the Seventy .
#
# Spanish:	No tendré que encender velas o lámparas de aceite a la noche para leer .
# Translation:	I will not be able to proceed on the oil of oil for night .
# Target:		I will not have to light <unk> or oil lamps at night to read .
#
# Spanish:	¿ Los trataríamos con más paciencia , más bondad y más tolerancia ? ” .
# Translation:	Do we treat them with more patience , kindness , and more than ? ”
# Target:		Would we treat them with more patience , more kindness , and more tolerance ? ”
#
# Spanish:	De ello testifico con gozo ; en el sagrado nombre de Jesucristo . Amén .
# Translation:	I testify that I testify with joy in the sacred name of Jesus Christ , amen .
# Target:		Of these things I joyfully testify in the sacred name of Jesus Christ , amen .
#
# Spanish:	Verdaderamente lo necesitamos en todo momento , sean momentos de sol o de lluvia .
# Translation:	We truly need to be all times in the time , or the healing of the healing .
# Target:		We truly need Him every hour , whether they be hours of sunshine or of rain .
#
# Spanish:	Con tracción en todas las ruedas , el camión salía disparado y <unk> trabajando .
# Translation:	She was in the middle of her car , she was working and she was working .
# Target:		With all wheels locked in and churning , the truck <unk> forward and our work continued .
#
# Spanish:	Llegan dificultades a nuestra vida , problemas que no <unk> y que jamás escogeríamos .
# Translation:	They become our difficulties , which is not happening and ever wait .
# Target:		<unk> come into our lives , problems we do not anticipate and which we would never choose .
#
# Spanish:	Y , como <unk> , hallamos a los becerros perdidos dormidos bajo la sombra .
# Translation:	And as you are engaged , you are under the lost .
# Target:		Sure enough , just as I had <unk> , we found our lost calves taking a <unk> in the shade .
#
# Spanish:	A último momento , el Maestro podría haberse vuelto atrás ; pero no lo hizo .
# Translation:	At the last time , the Master could have come back .
# Target:		At the last moment , the Master could have turned back .
#
# Spanish:	Primera oración : Élder Christoffel Golden Jr . Última oración : Obispo Richard C. Edgley .
# Translation:	Invocation : Elder Marcus Zwick , Bishop J. prayer , Richard C. Edgley .
# Target:		Invocation : Elder Christoffel Golden Jr. Benediction : Bishop Richard C. Edgley .
#
# Spanish:	Sean cuales sean sus circunstancias o las razones de ellas , ¡ ustedes son maravillosas !
# Translation:	Whatever your circumstances be of age or your reasons you are !
# Target:		Whatever your circumstances or the reasons for them , how wonderful you are .
#
# Spanish:	Aun sabiendo eso , el hermano menor salva al hermano malvado de una muerte segura .
# Translation:	Even knowing that , Brother Apilado saves the little wicked brother from a certain death .
# Target:		Even knowing this , the younger brother saves his wicked brother from certain death .
#
# Spanish:	Después de sus palabras , el coro cantará : " Siempre obedece los mandamientos " .
# Translation:	Following his remarks , the choir will sing : " Keep the commandments . "
# Target:		Following their remarks , the choir will sing : " Keep the Commandments . "
#
# Spanish:	Los miembros siempre son libres de hacer tales preguntas y procurar sinceramente mayor entendimiento ” .
# Translation:	Members are always free to do so , and seek to seek greater understanding . ”
# Target:		Members are always free to ask such questions and earnestly seek greater understanding . ”
#
# Spanish:	Les hablo a los padres de familia y a las familias de toda la Iglesia .
# Translation:	I speak to you fathers and family members .
# Target:		I speak to the fathers of the families and to families everywhere in the Church .
#
# Spanish:	De hecho , todos en el grupo comenzaron a formar un círculo apretado alrededor suyo .
# Translation:	Indeed , all of us grew up in the group began to host their circle .
# Target:		In fact , everyone in the group began to form a tight circle around him .
#
# Spanish:	Todo lo que tenía que hacer era abrir un <unk> , y allí los encontraba .
# Translation:	All who had to do it was to do , and they had found .
# Target:		All that I had to do is open a <unk> , and I would find them .
#
# Spanish:	Menciono los dos primeros atributos juntos , ser un ejemplo en palabra y en conducta .
# Translation:	I know the first two attributes , together become a word of choice and behavior .
# Target:		I mention the first two attributes together — being an example in word and in conversation .
#
# Spanish:	En cierto barrio , el Sacerdocio Aarónico primero observó y ahora sirve en forma valiosa .
# Translation:	In the ward , the Aaronic Priesthood was observed and is now a precious way .
# Target:		In one ward , Aaronic Priesthood holders first observed and now serve in a meaningful way .
#
# Spanish:	Él desea que estemos seguros y protegidos de las influencias del mundo a nuestro alrededor .
# Translation:	He wants us to be sure and protected from the world around us .
# Target:		He wants us to be safe and to be protected from the worldly influences all around us .
#
# Spanish:	Algunas permiten que firmes opiniones culturales o políticas <unk> su lealtad al evangelio de Jesucristo .
# Translation:	Some will stand strong for cultural traditions or their preaching the gospel of Jesus Christ .
# Target:		Some allow intense cultural or political views to weaken their allegiance to the gospel of Jesus Christ .
#
# Spanish:	Luego sentí que estaba parada en tierra firme y <unk> valor al pensar en Jesucristo .
# Translation:	I felt that I was standing strong and touching the courage of Jesus Christ .
# Target:		I then felt I was standing on solid ground and gained courage at the thought of Jesus Christ .
#
# Spanish:	Mi pareja estaba sentada en una pequeña <unk> como a medio metro uno del otro .
# Translation:	My couple sat in a little small little while serving as one another .
# Target:		My couple were seated on a little bench with about a full two feet ( 0.6 m ) of space between them .
#
# Spanish:	<unk> un discurso a sus hijos cada noche como un relato antes de irse a dormir .
# Translation:	She seeks a few words to lift each night as a story before leaving .
# Target:		Read an address to your children each night as a bedtime story .
#
# Spanish:	Los discursantes fueron seleccionados de entre las Autoridades Generales y los oficiales generales de la Iglesia .
# Translation:	The speakers were selected from the General Authorities and general officers of the Church .
# Target:		Speakers were selected from the General Authorities and general officers of the Church .
#
# Spanish:	Ahora me doy cuenta que yo estaba esperando recibir revelación sin haber antes pagado el precio .
# Translation:	I realize now that I was waiting for revelation without the price paid .
# Target:		I realize now that I had expected to receive revelation without paying the price .
#
# Spanish:	John <unk> el <unk> e informó rápidamente a sus dos amigos que era hora de partir .
# Translation:	John 17:4 and quickly . He informed their friends that was a time of a time .
# Target:		John <unk> and quickly informed his two friends that it was time to leave .
#
# Spanish:	Si tomamos la decisión incorrecta , no tenemos que culpar a nadie sino a nosotros mismos .
# Translation:	If we make choice , we have no choice to anyone else .
# Target:		If we make the wrong choice , we have no one to blame but ourselves .
#
# Spanish:	En mi opinión , el Libro de Mormón enseña la verdad con claridad y poder únicos .
# Translation:	In my mind , the Book of Mormon teaches truth with the only power and power of the only one - person .
# Target:		In my judgment , the Book of Mormon teaches truth with unique clarity and power .
#
# Spanish:	No retenemos el pago para ver cuál es la cantidad mínima con la que podemos escapar .
# Translation:	We do not use the fiery darts of the adversary is telling us that we can escape .
# Target:		We do n’t hold back to see what the minimum is we can get by with .
#
# Spanish:	La lujuria , por otro lado , no es para nada piadosa y celebra la <unk> .
# Translation:	A meager attempt to other side , is not quite aware of the unseen , and marvel at the banks .
# Target:		<unk> , on the other hand , is anything but godly and celebrates self - indulgence .
#
# Spanish:	Tengan presente que nuestros hijos y familiares ya eligieron seguir al Salvador en el reino premortal .
# Translation:	Be certain that our children and family chose to follow the Savior in the premortal kingdom .
# Target:		Remember , our children and family members already chose to follow the Savior in their premortal realm .
#
# Spanish:	El término el hombre natural puede referirse a cualquiera de nosotros si permitimos que lo sea .
# Translation:	The term man can be considered any of us if we allow Him to be .
# Target:		The term natural man can refer to any of us if we allow ourselves to be so .
#
# Spanish:	Ruego que el Espíritu Santo nos inspire y edifique mientras analizamos juntos estas verdades espirituales fundamentales .
# Translation:	I pray that the Holy Ghost will inspire and inspire us to consider these basic spiritual truths .
# Target:		I pray the Holy Ghost will inspire and edify us as we consider together essential spiritual truths .
#
# Spanish:	<unk> , él y su esposa avanzaron con fe , sin avergonzarse del evangelio de Jesucristo .
# Translation:	They are found , and their wife , boldly came from the gospel of Jesus Christ .
# Target:		<unk> , he and his wife went forward with faith , <unk> of the gospel of Jesus Christ .
#
# Spanish:	Es preciso enseñar y entender que amamos y respetamos a toda la gente que Lehi describió .
# Translation:	It is proposed that we teach and love that we respect all people who described that Lehi described as Lehi .
# Target:		It needs to be taught and understood that we love and respect all of the people whom Lehi described .
#
# Spanish:	mi amada esposa , Harriet , de quien me enamoré la primera vez que la vi ;
# Translation:	My dear wife , Harriet , who was raised me to the first time I saw .
# Target:		There is my beloved wife , Harriet , with whom I fell in love the first time I saw her .
#
# Spanish:	Lo más alentador de todo es que una fidelidad como esa “ nunca deja de ser ” .
# Translation:	The most kind of encouraging is a fidelity to “ never faileth . ”
# Target:		Most encouraging of all , such fidelity “ never faileth . ”
#
# Spanish:	En las Escrituras se nos enseña que el cuerpo y el espíritu constituyen el alma del hombre .
# Translation:	In the scriptures we are taught that the body and the spirit of man .
# Target:		Scripture teaches that the body and the spirit are the soul of man .
#
# Spanish:	La obra de historia familiar y del templo debe ser una parte habitual de nuestra adoración personal .
# Translation:	The work of family history and must be part of our personal worship .
# Target:		Family history and temple work should be a regular part of our personal worship .
#
# Spanish:	Hace algunos años , un joven maravilloso de nombre Curtis fue llamado a servir en una misión .
# Translation:	Some years ago a wonderful young man named Curtis was called to serve a mission .
# Target:		Some years ago a wonderful young man named Curtis was called to serve a mission .
#
# Spanish:	Nuestra doctrina es clara : las mujeres son hijas de nuestro Padre Celestial y Él las ama .
# Translation:	Our doctrine is clear : women are the Father of our Father and loves them .
# Target:		Our doctrine is clear : Women are daughters of our Heavenly Father , who loves them .
#
# Spanish:	Estoy orgulloso de los jóvenes de la Iglesia , y me regocijo en lo bueno que son .
# Translation:	I am proud of the young people of the Church , and I am in good .
# Target:		I am proud of the youth of the Church , and I rejoice in their goodness .
#
# Spanish:	Entonces Su Espíritu dejó Su cuerpo y Sus restos mortales fueron <unk> con amor en una tumba .
# Translation:	Then His Spirit would be left and His mortal body with a love for a Savior .
# Target:		Then His spirit left His body , and His mortal remains were placed lovingly in a tomb .
#
# Spanish:	Lo que se aprende en la Primaria las prepara para las verdades adicionales que aprenden de jovencitas .
# Translation:	What a Primary is learning to prepare for the truths of the Relief Society .
# Target:		The things you learn in Primary prepare you for the additional truths you learn as young women .
#
# Spanish:	¿ Piensan en Su humilde nacimiento , con el Salvador del mundo acostado en un pesebre ? .
# Translation:	Have His humble birth , with the Savior ’s birth , in a manger ?
# Target:		Do they think about His humble birth , the Savior of the world lying in a manger ?
#
# Spanish:	Creo que podemos suponer sin <unk> que los resultados serían similares en la mayor parte del mundo .
# Translation:	I believe that we can scarcely be misunderstood the results of greater greater greater than the world .
# Target:		I believe we can safely assume that the results would be similar in most parts of the world .
#
# Spanish:	“ Y el Señor , sí , el Salvador , estará en medio de su pueblo ” .
# Translation:	“ And the Lord , yes , the Savior shall be in his people . ”
# Target:		“ Then the Lord , … the Savior , shall stand in the midst of his people . ”
#
# Spanish:	Mi <unk> nunca será completo hasta que volvamos a reunirnos en la mañana de la Primera Resurrección .
# Translation:	My lamp is never to be a full - time in the morning of the First Quorum of the Twelve .
# Target:		I will never have a fulness of joy until we are reunited in the morning of the First Resurrection .
#
# Spanish:	Nuestra búsqueda debe convertirnos en discípulos amables , bondadosos , amorosos , tolerantes , pacientes y dedicados .
# Translation:	Our quest is to become disciples , submissive , loving , loving , patient , and dedicated .
# Target:		Our search should lead us to become kind , gentle , loving , forgiving , patient , and dedicated disciples .
#
# Spanish:	Hace ya años , mi tatarabuelo tuvo en sus manos el Libro de Mormón por primera vez .
# Translation:	Years ago my great - grandfather had in his hands for the Book of Mormon .
# Target:		Years ago my great - great - grandfather picked up a copy of the Book of Mormon for the first time .
#
# Spanish:	<unk> <unk> , “ Gracias , papá ” , Liahona , octubre de 1994 , pág. 45 .
# Translation:	Shelly Senior , “ Dad , ” Ensign , Oct. 1993 , 1994 , 45 .
# Target:		<unk> <unk> , “ Thanks , Dad , ” New Era , Apr. 1993 , 38 ; Tambuli , Oct. 1994 , 45 .
#
# Spanish:	Nuestro mundo es diferente ahora , los integrantes de la mayoría de las familias viven en diferentes lugares .
# Translation:	Our world is now different , most members of most different families live in different places .
# Target:		Our world is different now — the members of most families spread out .
#
# Spanish:	Para muchas personas , la interacción como iguales entre las razas era algo nuevo y representaba un desafío .
# Translation:	For many people , it was an interaction between the new and a new challenge .
# Target:		For many , the equality of interaction between the races was new and challenging .
#
# Spanish:	“ Y también todos los que reciben este sacerdocio , a mí me reciben , dice el Señor ;
# Translation:	“ And all that ye receive this priesthood , I will receive the priesthood , the Lord says unto me ;
# Target:		“ And also all they who receive this priesthood receive me , saith the Lord ;
#
# Spanish:	Poco después de escribir ese artículo , mi tío Vaughn sirvió en un barco en el océano Pacífico .
# Translation:	Soon after writing this article , my uncle Vaughn served in a car in the Pacific .
# Target:		Soon after submitting the article , Vaughn was assigned to sea duty in the Pacific theater .
#
# Spanish:	Proveer una formación académica para sus hijos es parte de ese cuidado , y es su responsabilidad sagrada .
# Translation:	A social - parent is to form of that sacred and is sacred .
# Target:		Providing an education for your children is part of that nurturing and is your sacred responsibility .
#
# Spanish:	Una manera es por medio de la adversidad , algo que todos experimentamos ( véase Alma 32:6 ) .
# Translation:	A way is why we experience , all of us ( see Alma 37:8 ) .
# Target:		One way is through that common lot we all share — adversity ( see Alma 32:6 ) .
#
# Spanish:	Hunter pasó sus primeros dos meses de vida en la unidad de cuidados intensivos <unk> de un hospital .
# Translation:	We crashed their first three months of life in unity as they universally ’ time to paint a hospital .
# Target:		Hunter spent his first two months of life in the <unk> intensive care unit of the hospital .
#
# Spanish:	En la época del Libro de Mormón , fue Zeezrom quien procuró destruir la fe de los creyentes .
# Translation:	In the time of the Book of Mormon , he sought to destroy faith in the believers .
# Target:		In Book of Mormon times , it was Zeezrom who sought to destroy the faith of the believers .
#
# Spanish:	El apóstol Santiago escribió que " la prueba de nuestra fe produce paciencia " ( Santiago 1:3 ) .
# Translation:	The Apostle James wrote that " the trial of our faith " brings " ( James 1:3 ) .
# Target:		The Apostle James wrote that " the trying of our faith worketh patience " ( James 1:3 ) .
#
# Spanish:	El élder Cook enseña que debemos sacrificarnos y tener la humildad necesaria para fortalecer nuestra fe en Jesucristo .
# Translation:	Elder Cook teaches that we must build our understanding and strengthen our faith in Jesus Christ .
# Target:		Elder Cook teaches that we must sacrifice and have the necessary humility to strengthen our faith in Jesus Christ .
#
# Spanish:	Es importante porque la calidad de nuestro futuro eterno es proporcional a nuestra habilidad de perseverar en rectitud .
# Translation:	It is important because it is as our future of our eternal ability to endure in righteousness .
# Target:		It is important because the quality of our eternal future is proportional to our ability to endure in righteousness .
#
# Spanish:	Hermanos y hermanas , muchas cosas son buenas , muchas son importantes , pero sólo algunas son esenciales .
# Translation:	Brothers and sisters , many things are good things , but some are essential .
# Target:		Brothers and sisters , many things are good , many are important , but only a few are essential .
#
# Spanish:	Entonces , al pedir la ayuda del Señor , Él los bendecirá con Su Espíritu y Su palabra .
# Translation:	Then , as you ask the Lord ’s help , He will bless you with His Spirit and His word .
# Target:		Then as you ask for the Lord ’s help , He will bless you with His Spirit and His word .
#
# Spanish:	La paz que irradiaba la hermana Packer junto a su esposo en sus últimas horas sobrepasa todo entendimiento .
# Translation:	The peace that Sister Packer walked back to his husband in his final hours , all of his understanding .
# Target:		As Sister Packer sat next to her husband in his final hours , she radiated that peace that passes all understanding .
#
# Spanish:	“ Vosotros sois la luz del mundo ; una ciudad <unk> sobre un monte no se puede esconder .
# Translation:	“ Ye are the light of the world ; they can not be a mountain of a mountain without a mountain of sand .
# Target:		“ Ye are the light of the world . A city that is set on an hill can not be hid .
#
# Spanish:	Fue extraordinario no sólo poder terminar el recorrido , sino también poder acelerar al acercarme a la meta .
# Translation:	It was not only possible only the power , but the power also to draw near to me .
# Target:		It was a great feeling to not only be able to run the course but also to accelerate down the stretch to the finish line .
#
# Spanish:	En <unk> , un hombre que está muerto de hambre se preocupa por el bienestar de un bebé huérfano .
# Translation:	In a man , a man who is born of a successful village in the middle of a baby .
# Target:		A starving man in <unk> is concerned for the welfare of an orphaned baby .
#
# Spanish:	Cuarto , aprendamos a servir a los demás y a pensar en ellos incluso en las épocas de tribulación .
# Translation:	Fourth , we learn to serve others and think about them in times of crisis .
# Target:		Fourth , learn to serve and think of others even in our times of trial .
#
# Spanish:	Y nunca se sabe , pero tal vez ustedes sean el ejemplo que mi pequeña Ruby necesite algún día .
# Translation:	And never it is , but it may be my small example that my small example .
# Target:		And you never know — you might be the example my little Ruby will need someday .
#
# Spanish:	Además , es el elemento <unk> que garantiza que pueda <unk> por la entrada o abertura que está debajo .
# Translation:	In addition , it is proposed that we sustain the promotion or snow .
# Target:		And it is the structural element that ensures the gate , or opening below , is <unk> .
#
# Spanish:	El Salvador , por ejemplo , era un humilde carpintero , pero eso de ninguna manera definió Su vida .
# Translation:	The Savior , for example , was humble but that is not a way of life .
# Target:		The Savior , for example , was a humble carpenter , but that hardly defined His life .
#
# Spanish:	El participar de la Santa Cena dignamente fortalece nuestra relación personal con la roca fundamental , que es Jesucristo .
# Translation:	The sacrament to partake of the sacrament will strengthens our personal relationship with the rock of Jesus Christ .
# Target:		Worthily partaking of the sacrament strengthens our personal connection to the foundation rock , even to Jesus Christ .
#
# Spanish:	Cada vez que un grupo de miembros de la Iglesia le pedía que les hablara , él lo hacía .
# Translation:	Every group of members asked him to speak of the Church , he would speak to him .
# Target:		Whenever some group of Latter - day Saints asked him to speak to them , he did it .
#
# Spanish:	Yo no te <unk> completamente , y en el día de la ira me acordaré de tener misericordia ” .
# Translation:	I do not condemn thee , and not completely at age age , I will remember the mercy of mercy . ”
# Target:		I will not utterly cast you off ; and in the day of wrath I will remember mercy . ”
#
# Spanish:	“ nada hago por mí mismo , sino … como el Padre me enseñó ” ( Juan 8:28 ) .
# Translation:	“ I do nothing but the same , but the Father taught me ” ( John 8:28 ) .
# Target:		“ I do nothing of myself ; but as my Father hath taught me ” ( John 8:28 ) .
#
# Spanish:	Y aún así , él clamó : “ Padre , perdónalos , porque no saben lo que hacen ” .
# Translation:	And so , it still came , “ Father , forgive them ; for they know what they do . ”
# Target:		And yet He cried out , “ Father , forgive them ; for they know not what they do . ”
#
# Spanish:	Mi Padre Celestial me <unk> para <unk> mi impaciencia , desarrollar compasión y para consolar a los que sufren .
# Translation:	My Father in Heaven reaches out to my talents , and mercy to comfort those who suffer .
# Target:		Heavenly Father <unk> me to temper my impatience , to develop empathy , and to comfort those who are suffering .
#
# Spanish:	En este sueño , Lehi vio un campo grande con un árbol maravilloso de una belleza imposible de describir .
# Translation:	In this dream , Lehi saw a great picture with a marvelous tree of beauty .
# Target:		In his dream , Lehi saw a vast field , and in it was a wondrous tree , beautiful beyond description .
#
# Spanish:	Ésa es verdaderamente la esperanza que todos debemos tener ; es lo que nos distingue del resto del mundo .
# Translation:	That is true that we must have all . It is what is happening from the world .
# Target:		This is truly the hope we must all have . It is what sets us apart from the rest of the world .
#
# Spanish:	<unk> el pabellón cuando sentimos y oramos : “ Hágase Tu voluntad ” y “ a Tu tiempo ” .
# Translation:	Let ’s start when we feel and pray , “ Thy will be done ” and “ will be returned to your time . ”
# Target:		We remove the pavilion when we feel and pray , “ Thy will be done ” and “ in Thine own time . ”
#
# Spanish:	Son atacados por todos lados por " … los ardientes dardos del adversario " y requieren refuerzo y apoyo .
# Translation:	They are all about " the " fiery darts of the adversary " and " enabled them to support and support them .
# Target:		They are being attacked on every side by " the fiery darts of the adversary " and are in need of reinforcement and support .
#
# Spanish:	Niños de alrededor del mundo respondieron con entusiasmo a una campaña de servicio <unk> por las revistas de la Iglesia .
# Translation:	Children around the world responded with a enthusiasm for service of the Church is usually sung by the Church .
# Target:		Children around the world enthusiastically responded to a service campaign launched by Church magazines .
#
# Spanish:	En las palabras de mi amigo no había el más mínimo grado de queja , de rebeldía o de disconformidad .
# Translation:	In the words of my friend had no more than he declared , the heavens or from the midst of the workings of the Incas .
# Target:		My friend ’s words contained not the slightest degree of complaint , rebelliousness , or discontent .
#
# Spanish:	Se le <unk> con un azote de múltiples tiras de cuero en las que se <unk> <unk> y huesos <unk> .
# Translation:	They are content to be with a dragging - off - old pine - covered slopes , which is remarkably pervasive .
# Target:		He was scourged with a whip into whose multiple leather strands sharp <unk> and bones were woven .
#
# Spanish:	Pude sentir el amor que mi obispo tenía por alguien que a mí me parecía un enemigo <unk> y rebelde .
# Translation:	I could feel the love that my bishop had someone who seemed to me and to be a wounded , and soft sheep .
# Target:		I felt my bishop ’s love for someone who seemed to me an unlovable and rebellious enemy .
#
# Spanish:	Todos nosotros , jóvenes y adultos , afrontamos a diario la guerra a la que se refirió el presidente Monson .
# Spanish:	El presidente Gordon B. Hinckley dijo : “ Será un día maravilloso , hermanos , será un día en que se cumplan los propósitos del Señor , cuando nuestros quórumes del sacerdocio se <unk> en un ancla de fortaleza para cada uno de sus miembros , cuando todo hombre pueda decir con propiedad : ‘ Soy miembro de un quórum del sacerdocio de La Iglesia de Jesucristo de los Santos de los Últimos Días .
# Translation:	President Gordon B. Hinckley said : “ It will be a wonderful day , will be one day in the Lord ’s purposes , when our priesthood quorums , to be an end of the Church members , as a man , to say , ‘ The body of Jesus Christ of Latter - day Saints , I am
# Target:		President Gordon B. Hinckley once said : “ It will be a marvelous day , my brethren — it will be a day of fulfillment of the purposes of the Lord — when our priesthood quorums become an anchor of strength to every man belonging <unk> , when each such man may appropriately be able to say , ‘ I am a member of a priesthood quorum of The Church of Jesus Christ of Latter - day Saints .
#
# Spanish:	El presidente Wilford Woodruff enseñó : “ Todo hombre y toda mujer que haya entrado alguna vez en la Iglesia de Dios y haya sido bautizado para la remisión de los pecados tiene derecho a la revelación , derecho a tener el Espíritu de Dios para <unk> en sus labores , en el cuidado de los hijos , en los consejos que den a sus hijos y a aquellos a quienes hayan sido llamados a presidir .
# Translation:	President Wilford Woodruff taught : “ Every man and woman who has once again in the Church of God and has been baptized for the remission of sins , has been called to the sins of the Spirit , to be accountable to their children , to God ’s children , to preside over their children in order to
# Target:		President Wilford Woodruff taught : “ Every man or woman that has ever entered into the church of God and been baptized for the remission of sins has a right to revelation , a right to the Spirit of God , to assist them in their labors , in their administrations to their children , in counseling their children and those over whom they are called upon to preside .
#
# Spanish:	En un artículo para la revista Liahona en 2003 , hice hincapié en cuatro áreas que podrían crear ceguera teológica y el tropiezo que Jacob describió : el sustituir las filosofías de los hombres por las verdades del Evangelio , el fanatismo religioso , los gestos heroicos como un sustituto para la consagración diaria y el elevar las normas sobre la doctrina ( véase Traspasar lo señalado , Liahona , marzo de 2003 , págs . 21–24 ) .
# Translation:	In a article he was placed in the Liahona and Ensign , Nov. 2003 , be able to create the tradition of Nephi , which described : The Gospel of Elijah , to provide the gospel , the religious , as a few religious imperative , to be a daily , the doctrine , to the doctrine , to
# Target:		In an article I wrote for Church magazines in 2003 , I emphasized four areas that could create theological blindness and the stumbling that Jacob described : <unk> the philosophies of men for gospel truths , gospel extremism , heroic gestures as a substitute for daily consecration , and elevating rules over doctrine ( see Looking beyond the Mark , Ensign , Mar. 2003 , 41–44 ; Liahona , Mar. 2003 , 21–24 ) .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-3232d09dd0f5> in <module>
#      23     src = batch.src.transpose(0, 1)[:1].cuda()
#      24     src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
# ---> 25     out = greedy_decode(model, src, src_mask,
#      26                         max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
#      27     print("Spanish:", end="\t")
#
# <ipython-input-96-3232d09dd0f5> in greedy_decode(model, src, src_mask, max_len, start_symbol)
#      11         next_word = next_word.data[0]
#      12         ys = torch.cat([ys,
# ---> 13                         torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
#      14     return ys
#      15
#
# KeyboardInterrupt:
